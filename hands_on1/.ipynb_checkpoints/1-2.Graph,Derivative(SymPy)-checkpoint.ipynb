# %% [markdown]
# # 関数のグラフ

# %%
import sympy as sym
from sympy.plotting import plot
sym.init_printing(use_unicode=True)

# %% [markdown]
# ## SymPyの基本文法

# %%
# 変数の定義
x = sym.symbols("x")

# %%
# 変数の定義
a, b, c, d, x, y, t = sym.symbols("a b c d x y t")

# %%
# 数式の記述
y = x**2-12*x+8
y
# Out:
#  2
# x  - 12⋅x + 8

# %% [markdown]
# ## 代表的な関数のグラフ（二次関数，三角関数，指数関数など）の描画

# %%
# SymPyで関数の図示（二次関数）
y = x**2+4*x+4
y
# Out:
#  2
# x  + 4⋅x + 4

# %%
plot(y)
#plot(f, (x, -20, 20))

# %%
# 三角関数
y1 = sym.cos(x)
y2 = sym.sin(x)

# %%
# 関数の図示
plot(y1, y2, (x, -2*sym.pi, 2*sym.pi))

# %%
# 対数関数
y1 = sym.exp(x)
y2 = sym.log(x)

# %%
plot((y1, (x, -2.00, 2.00)), (y2, (x, 0.01, 4.00)))

# %% [markdown]
# # 微分

# %% [markdown]
# ## 微分を定義から丁寧に

# %% [markdown]
# ## 数値微分の実装

# %% [markdown]
# ## SymPyによる微分

# %%
y = x**2
y
# Out:
#  2
# x

# %%
plot(y, (x, -3, 5))

# %%
# 微分の式
sym.Derivative(y)
# Out:
# d ⎛ 2⎞
# ──⎝x ⎠
# dx

# %%
# 微分を計算する
sym.Derivative(y).doit()
# Out:
# 2⋅x

# %%
# 微分を計算する（別の方法）
sym.diff(y)
# Out:
# 2⋅x

# %%
# xについて微分して x=1を代入
sym.diff(f).subs(x, 1)
# Out:
# 2

# %% [markdown]
# ## 最小値問題（発展）

# %% [markdown]
# # 演習問題

# %% [markdown]
# ## 関数のグラフ

# %% [markdown]
# 次の関数を図示せよ。

# %% [markdown]
# (1)
# $$
# y = x^2 + 4x + 1
# $$

# %% [markdown]
# (2)
# $$
# y = x^3 + 3x^2 - 9x + 4
# $$

# %% [markdown]
# (3)
# $$
# y = x^4 - 2x^3 +1
# $$

# %% [markdown]
# (4)
# $$
# y = \sin 3x
# $$

# %% [markdown]
# (5)
# $$
# y = 4\cos^2 x
# $$

# %% [markdown]
# (6)
# $$
# y = e^{-x}
# $$

# %% [markdown]
# (7)
# $$
# y = 2^x
# $$

# %% [markdown]
# (8)
# $$
# y = \log_e x
# $$

# %% [markdown]
# (9)
# $$
# y = \log_3 x
# $$

# %% [markdown]
# ## 微分

# %% [markdown]
# 上の関数について，それぞれ1階微分を求めよ。また，極値を求めよ。
#
# （発展：2階微分を求め，変曲点を求めよ。）

# %% [markdown]
# （発展2：数値微分について，より精度の高い手法について調べ，そのコードを書け。）
